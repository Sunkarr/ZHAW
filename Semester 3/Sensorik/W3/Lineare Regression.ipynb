# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = [12,16,71,99,45,27,80,58,4,50]
y = [56,22,37,78,83,55,70,94,12,40]
x = np.array(x).reshape(-1,1)
y = np.array(y).reshape(-1,1)
x
# Out:
# array([[12],
#        [16],
#        [71],
#        [99],
#        [45],
#        [27],
#        [80],
#        [58],
#        [ 4],
#        [50]])

# %%
y
# Out:
# array([[56],
#        [22],
#        [37],
#        [78],
#        [83],
#        [55],
#        [70],
#        [94],
#        [12],
#        [40]])

# %%
linreg = LinearRegression().fit(x,y)

linreg.intercept_
# Out:
# array([31.82863093])

# %%
linreg.coef_
# Out:
# array([[0.49505128]])

# %%
linreg.score(x, y)
# Out:
# 0.3343851657453447

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook
plt.scatter(x,y)
ax = plt.gca()
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.plot(x,linreg.intercept_+linreg.coef_*x, color='r')
# Out:
# <div id='ac34fe50-6d0f-46b2-ae18-6448c69d3dd7'></div>

# %%
y = [24,32,140,200,83,55,160,120,8,100]
y = np.array(y).reshape(-1,1)
y
# Out:
# array([[ 24],
#        [ 32],
#        [140],
#        [200],
#        [ 83],
#        [ 55],
#        [160],
#        [120],
#        [  8],
#        [100]])

# %%
linreg = LinearRegression().fit(x,y)

linreg.intercept_
# Out:
# array([-0.67795244])

# %%
linreg.coef_
# Out:
# array([[2.01034529]])

# %%
linreg.score(x, y)
# Out:
# 0.9979915704037939

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook
plt.scatter(x,y)
ax = plt.gca()
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.plot(x,linreg.intercept_+linreg.coef_*x, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
