# %% [markdown]
# #### Read data
#
# In order to use Spark and its DataFrame API, we will need to use a SQLContext. When running Spark, we start Spark application by creating a SparkContext. We can then create a SQLContext from the SparkContext.
#
# Read the data "nycflights" into a Spark DataFrame with the read method.

# %%
print("#TODO")
#spark_DF =
# Out:
# #TODO

# %% [markdown]
# Let's display the first 1000 rows.

# %%
print("#TODO")
# Out:
# #TODO

# %% [markdown]
# But how many rows do we have in the data frame?

# %%
print("#TODO")
# Out:
# #TODO

# %% [markdown]
# Before doing any analysis, let's see the schema. We can also see the type of the DataFrame.

# %%
#TODO: Print the schema

# %%
print("#TODO: Print the Type")
# Out:
# #TODO: Print the Type

# %% [markdown]
# ##### Spark Operations
#
# Now, let's perform various Spark DataFrame operations.

# %% [markdown]
# Select all columns and display the data

# %%
# TODO

m = ""

display(m)
# Out:
# ''

# %% [markdown]
# Select the columns 'year', 'month' and 'day' and show the data

# %%
print("#TODO: Select the columns 'year', 'month' and 'day' and show the data")
# Out:
# #TODO: Select the columns 'year', 'month' and 'day' and show the data

# %% [markdown]
# drop the column 'month' and display the data

# %%
print("TODO: drop the column 'month' and display the data")
# Out:
# TODO: drop the column 'month' and display the data

# %% [markdown]
# Change the column names of year, month and day to upper case and display it.

# %%
print("TODO: change the column names of year, month and day to upper case and display it")
# Out:
# TODO: change the column names of year, month and day to upper case and display it

# %% [markdown]
# Display the column origin and a second column with the length of the origin string.

# %%
from pyspark.sql.functions import length

print("TODO: Display the origin and the length of the origin string.")
# Out:
# TODO: Display the origin and the length of the origin string.

# %% [markdown]
# Filter the column month for January.

# %%
print("TODO: Filter the column month for January.")
# Out:
# TODO: Filter the column month for January.

# %% [markdown]
# Filter the column month for all months after September.

# %%
print("TODO: Filter the column month for all months after September.")
# Out:
# TODO: Filter the column month for all months after September.

# %% [markdown]
# Filter the column month for all months between September and May (including May).

# %%
print("TODO: Filter the column month for all months between September and May (including May).")
# Out:
# TODO: Filter the column month for all months between September and May (including May).

# %% [markdown]
# Use [`distinct()`](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.distinct) filters out duplicate rows, and it considers all columns.

# %%
print("TODO: Filter the column month for all months between September and May (including May) with applying distinct.")
# Out:
# TODO: Filter the column month for all months between September and May (including May) with applying distinct.

# %% [markdown]
# use `where()` as an alias for `filter()` and query for all month before April (including April).

# %%
print("TODO: use `where()` as an alias for `filter()` and query for all month before April (including April)")
# Out:
# TODO: use `where()` as an alias for `filter()` and query for all month before April (including April)

# %% [markdown]
# use `where()` as an alias for `filter()` and query the column month for december.

# %%
print("TODO: use where() as an alias for filter() and query the column month for december.")
# Out:
# TODO: use where() as an alias for filter() and query the column month for december.

# %% [markdown]
# Implement a user defined function to query for even months only

# %%
from pyspark.sql.types import BooleanType

print("TODO: Implement a user defined function to query for even months only")
# Out:
# TODO: Implement a user defined function to query for even months only

# %% [markdown]
# Implement a user defined function to query for June-August and December

# %%
print("TODO: Implement a user defined function to query for June-August and December")
# Out:
# TODO: Implement a user defined function to query for June-August and December

# %% [markdown]
# [`groupBy()`]((http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.groupBy) is one of the most powerful transformations. It allows you to perform aggregations on a DataFrame.
#
# Unlike other DataFrame transformations, `groupBy()` does _not_ return a DataFrame. Instead, it returns a special [GroupedData](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData) object that contains various aggregation functions.
#
# The most commonly used aggregation function is [count()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData.count),
# but there are others (like [sum()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData.sum), [max()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData.max), and [avg()](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData.avg).
#
# These aggregation functions typically create a new column and return a new DataFrame.
#
# Group by the columns 'carrier' and calculate the average distance per group.

# %%
print("TODO: Group by the columns 'carrier' and calculate the average distance per group.")
# Out:
# TODO: Group by the columns 'carrier' and calculate the average distance per group.

# %% [markdown]
# Averages of groups using DataFrames. [`orderBy()`](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.distinct) allows you to sort a DataFrame by one or more columns, producing a new DataFrame.
#
# Order the result above by the column carrier.

# %%
print("TODO: Order the result above by the column carrier")
# Out:
# TODO: Order the result above by the column carrier

# %% [markdown]
# in orderBy(), the default is ascending but we can change it to descending by setting "ascending=False".
#
# Order the above result in descending order.

# %%
print("TODO: Order the above result in descending order")
# Out:
# TODO: Order the above result in descending order

# %% [markdown]
# Use the [`count` function](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.GroupedData.count) to find the number of times each carrier occurs

# %%
print("TODO: Use the count function to find the number of times each carrier occurs")
# Out:
# TODO: Use the count function to find the number of times each carrier occurs

# %% [markdown]
# We can also calculate maximum, minimum and sum of groups using DataFrames

# %%
print("TODO: calculate maximum of the distance and hour column per carrier group.")
# Out:
# TODO: calculate maximum of the distance and hour column per carrier group.

# %%
print("TODO: calculate minimum of the distance and hour column per carrier group.")
# Out:
# TODO: calculate minimum of the distance and hour column per carrier group.

# %%
print("TODO: calculate sum of the distance and hour column per carrier group.")
# Out:
# TODO: calculate sum of the distance and hour column per carrier group.

# %% [markdown]
# ### SQL statements in Spark

# %%
 # SQL statements can be run by using the sql methods provided by `spark`
  
print("TODO: Register this DataFrame as a table.")
# Out:
# TODO: Register this DataFrame as a table.

# %% [markdown]
# write a SQL query for query for month >= 5 and <= 9

# %%
print("TODO: write a SQL query for query for month >= 5 and <= 9")
# Out:
# TODO: write a SQL query for query for month >= 5 and <= 9

# %% [markdown]
# write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order.

# %%
print("TODO: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order.")
# Out:
# TODO: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order.

# %% [markdown]
# write a SQL query to get the distinct carriers.

# %%
print("TODO: write a SQL query to get the distinct carriers.")
# Out:
# TODO: write a SQL query to get the distinct carriers.

# %% [markdown]
# write a SQL query to get distinct months.

# %%
print("TODO: write a SQL query to get distinct months.")
# Out:
# TODO: write a SQL query to get distinct months.

# %% [markdown]
# write a SQL query to get distinct months between >3 and <10.

# %%
print("TODO:  write a SQL query to get distinct months between >3 and <10.")
# Out:
# TODO:  write a SQL query to get distinct months between >3 and <10.

# %% [markdown]
# write a SQL query to get distinct months between 4 and 9

# %%
 print("TODO: write a SQL query to get distinct months between 4 and 9.")
# Out:
# TODO: write a SQL query to get distinct months between 4 and 9.

# %% [markdown]
# write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and limit to 5.

# %%
print("TOD: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and limit to 5")
# Out:
# TOD: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and limit to 5

# %% [markdown]
# write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and just with maximum_distance > 2000.

# %%
print("TODO: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and just with maximum_distance > 2000")
# Out:
# TODO: write a SQL query for query the carrier and max(distance) AS Maximum_Distance grouped by carrier and ordered by Maximum_Distance in descending order and just with maximum_distance > 2000

# %% [markdown]
# write a SQL query to query for all months not equal 2

# %%
print("TODO: write a SQL query to query for all months not equal 2")
# Out:
# TODO: write a SQL query to query for all months not equal 2

# %% [markdown]
# write a SQL query to query for carriers where month = 1 or month = 12

# %%
print("TODO: write a SQL query to query for carriers where month = 1 or month = 12")
# Out:
# TODO: write a SQL query to query for carriers where month = 1 or month = 12

# %% [markdown]
# write a SQL query to query for all distinct carriers starting with an A

# %%
print("TODO: write a SQL query to query for all distinct carriers starting with an A")
# Out:
# TODO: write a SQL query to query for all distinct carriers starting with an A
