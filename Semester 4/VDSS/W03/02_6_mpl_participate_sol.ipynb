# %% [markdown]
# # Matplotlib Practice

# %%
import matplotlib.pyplot as plt

# %%
# makes the inline-figures in notebooks look crisper
# %config InlineBackend.figure_format = 'svg'

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 4]

# %% [markdown]
# `To do`:
# * initiate a new Figure and Axes with it (mpl pattern!)
# * add a line chart using the data `x` and `y`
# * display the plot

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# `To do`:
# * create a scatter plot based on the dame data `x` and `y`

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.show()

# %% [markdown]
# `To do`:
# * Combine scatterplot and line chart (-> connected scatterplot) on the same `Axes`

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
ax.scatter(x, y)
plt.show()

# %% [markdown]
# `To do`:
# * create two connected scatterplots from two data series on the same Axes

# %%
x_1 = [1, 2, 3, 4, 5]
y_1 = [5, 4, 3, 2, 4]

x_2 = [0.5, 1.5, 2.5, 3.5, 4.5]
y_2 = [3, 5, 2, 4, 3]

# %%
fig, ax = plt.subplots()
ax.plot(x_1, y_1)
ax.scatter(x_1, y_1)

ax.plot(x_2, y_2)
ax.scatter(x_2, y_2)
plt.show()

# %% [markdown]
# ☝️ You can draw multiple elements on the same `Axes` on top of each other
#
# ☝️ Matplotlib has a builtin logic that varies `color` and other design elements over such collections if you do not specify them explicitly

# %% [markdown]
# `To do`:
# * Can you reproduce this figure?
#
# <img src="pics/exercise_1-1.png">
#
# 👉 We can work with mutliple Axes on the same Figure
#
# Here's the data and some code to get you started.

# %%
import numpy as np

# %%
# Our data...
x = np.linspace(0, 10, 100)
y1, y2, y3 = np.cos(x), np.cos(x + 1), np.cos(x + 2)
names = ['Signal 1', 'Signal 2', 'Signal 3']

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(10,7)) # figsizes in inches

for i, y in enumerate([y1, y2, y3]):
    axs[i].plot(x, y, color='black')  # 
    axs[i].set_title(names[i], fontsize=16)
    
    # Remove all ticks
    # axs[i].tick_params(axis='both', which='both', length=0)
    # axs[i].set(xticks=[], yticks=[])
    # alternative:
    axs[i].xaxis.set_visible(False)
    axs[i].yaxis.set_visible(False)
    
    # axs[i].set_xlim([x.min(), x.max()])
    # axs[i].set_ylim([y.min(), y.max()])
    axs[i].margins(0)

plt.show()

# %% [markdown]
# `To do`:
# * create an area chart using the `fill_between()` method
# * it has two required arguments, `x` and `y1`
# * additionally, there is an optional `y2` argument, which defaults to 0.
# * modify the y2 argument to understand the impact it has on the chart.

# %%
x = [1, 2, 3, 4, 5, 6]
y = [12, 8, 15, 6, 10, 4]

# %%
fig, ax = plt.subplots()
ax.fill_between(x, y)
plt.show()

# %% [markdown]
# `To do`:
# * create a pie chart using the `pie()` method. It takes a `x` and an optional `labels` argument.

# %%
x = [16, 8, 6, 20, 15]
labels = ["Nike", "Adidas", "Asics", "Puma", "Jordan"]

# %%
fig, ax = plt.subplots()
ax.pie(x, labels=labels)
plt.show()

# %% [markdown]
# `To do`:
# * create a horizontal bar plot from the provided dataset using the `barh()` function
# * `barh()` takes two arguments: `y` and `width`
# * What happens if you use the `bar()` function instead of `barh()`?

# %%
y = [
   "Apple",
   "Banana",
   "Cherry",
   "Date",
   "Elderberry",
   "Fig"
]
width = [12, 8, 15, 6, 10, 4]

# %%
fig, ax = plt.subplots()
ax.barh(y, width)
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(y, width)
plt.show()

# %% [markdown]
# `To do`:
# * create an histogram using the `ax.hist()` method

# %%
x = [
   10, 12, 11, 13,
   15, 17, 12, 16,
   15, 21, 9, 14,
   14, 15, 13
]

# %%
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# `To do`:
# * create a boxplot using the `boxplot()` method. It takes a `x` argument.

# %%
x = [16, 8, 6, 20, 15]

# %%
fig, ax = plt.subplots()
ax.boxplot(x)
plt.show()

# %% [markdown]
# `To do`: Create a horizontal bar plot using `ax.barh()` on the provided data with the following specifications:
# * The bars are "orange".
# * The bar height is smaller than the default value.

# %%
x = [10, 20, 30, 40]
labels = ["France", "Japan", "Italy", "Spain"]

# %%
fig, ax = plt.subplots()
ax.barh(labels, x, color="orange", height=0.8)
plt.show()

# %% [markdown]
# `To do`: Create a scatter plot using `ax.scatter()` with the following properties:
# * the points are "black"
# * the point size is 100
# * the point edges are "red"
# * the edge width is thick

# %%
x = [10, 20, 30, 40]
y = [30, 20, 80, 10]

# %%
fig, ax = plt.subplots()
ax.scatter(
   x, y,
   s=100,
   color="black",
   edgecolor="red",
   linewidth=3
)
plt.show()

# %% [markdown]
# `To do`: Create a histogram using `ax.hist()` with the following features:
# * the bars are "pink"
# * the histogram contains exactly 5 bins
# * the bar borders are "black"

# %%
x = [
   10, 12, 11, 13,
   15, 17, 12, 16,
   15, 21, 9, 14,
   14, 15, 13
]

# %%
fig, ax = plt.subplots()
ax.hist(
   x,
   color="pink",
   bins=5,
   edgecolor="black"
)
plt.show()

# %% [markdown]
# `To do`:
# - initiate a new figure and axes with it
# - add a line chart using the data `x` and `y`
# - add a text in the middle of the **Axes** with your name
# - display the result

# %%
x = [1,2,3,4,5]
y = [2,3,1,4,5]

# %%
fig, ax = plt.subplots()

ax.plot(x, y)
ax.text(3, 3, "Hi! I'm Manuel")

plt.show()

# %% [markdown]
# `To do`:
#
# - move the text with your name to the top left of the Axes
# - display the result

# %%
x = [1,2,3,4,5]
y = [2,3,1,4,5]

# %%
fig, ax = plt.subplots()

ax.plot(x, y)
ax.text(1, 5, "Hi! I'm Manuel")

plt.show()

# %% [markdown]
# `To do`:
# * initiate a new Figure and Axes with it
# * add a line chart
# * add a text in the **middle of the Figure** with your name
# * display the result

# %%
x = [1,2,3,4,5]
y = [2,3,1,4,5]

# %%
fig, ax = plt.subplots()

ax.plot(x, y)
fig.text(0.5, 0.5, "Hi! I'm Manuel")

plt.show()

# %% [markdown]
# `To do`:
# * move the text with your name to the top left of the Figure
# * display the result

# %%
x = [1,2,3,4,5]
y = [2,3,1,4,5]

# %%
fig, ax = plt.subplots()

ax.plot(x, y)
fig.text(0.1, 0.9, "Hi! I'm Manuel")

plt.show()

# %% [markdown]
# `To do`:
# * initiate a new Figure and Axes with it
# * add a line chart
# * add a text in the Figure with your name
# * add a text in the Axes with your neighbour's name
# * display the result

# %%
x = [1,2,3,4,5]
y = [2,3,1,4,5]

# %%
fig, ax = plt.subplots()

ax.plot(x, y)
fig.text(0.1, 0.9, "Hi! I'm Manuel")
ax.text(3, 4, "Hi! I'm Oliver")

plt.show()
