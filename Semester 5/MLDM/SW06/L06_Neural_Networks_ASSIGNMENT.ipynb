# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

RANDOM_SEED = 0xdeadbeef

# %% [markdown]
# # Neural Networks: Part 1
#
# In this lab we will look at the following:
#
# 1. Architecture of a neural network with one hidden layer
# 2. Computing the forward pass by hand
# 3. Implementing it using numpy only
#     - Implement Forward Pass
#     - Computing the gradients using Stochastic Gradient Descent
#     - Updating the weights
# 4. Implement the neural network using Keras
#
# ## Task 1: Neural Networks Forward Pass by Hand (2 Points)
#
# In this task we use a simple neural network with one hidden layer, and show how to implement it from scratch.

# %% [markdown]
# ![NN1.png](data:image/png;base64,...)![Alt text](https://github.com/alisarupenyan/MLDM_HS2025/blob/main/L09_1-1_v1.dio.svg?raw=1)

# %% [markdown]
# In the figure above, you see the diagram of a feed-forward neural network.
#
# - 2 input nodes:        $x_1$ and $x_2$
# - 3 hidden nodes:       $h_1$, $h_2$ and $h_3$
# - 1 output node:        $\hat{y}$
#
# Here are some details on the variables:
#
# |Variable|Name|Dimensions|Notes|
# |-|-|-|-|
# |$X$|Input matrix|($m$,2)|Input to the neural network. Each row corresponds to a sample in the training set ($m$ is the sample size or the batch size).|
# |$x$|Input |(2,1)|Single input. We have two features each in one row.|
# |$W$|Weights from input to hidden layer|(2,3)|The number of columns equals the number of nodes in the hidden layer. The number of rows equals to the number of attributes for the observation in our training set.|
# |$h_1, h_2, h_3$|Output of the hidden layer|($m$,3)|The number of columns equals the number of nodes in the hidden layer. The number of rows equals to the number of samples in the training set.|
# |$u$|Weights from hidden to output layer|(3,1)|The number of rows match the number of nodes in the hidden layer.|
# |$\hat{y}$|Model Output|(m,1)|The number of rows match the number of samples in the training set (batch).|
#
#
# Each edge has a weight which is multiplied with the output of the node on the left and sent as input to the node on the right.
#
# The $\sigma$ denotes activation function which is applied in the nodes of the hidden layer and the output layer.
#
# > *__Note__: We do not use biases for the nodes to keep calculations simple.*

# %% [markdown]
# We write $NN(x, W, u)$ to denote the function computed by the above neural network.

# %% [markdown]
# <hr />
#
# ### Compute a single output
#
# The full formula to compute a single output for this network is:
#
# \begin{align}
#   \hat{y} &= NN(x, W, u) \\
#   &= \sigma(u_1\sigma(w_{11}x_1 + w_{21}x_2) + u_2\sigma(w_{12}x_1 + w_{22}x_2) + u_3\sigma(w_{13}x_1 + w_{23}x_2)) \\
#   &= \sigma(\sum_{i = 1}^{3} u_i\sigma(w_{1i}x_1 + w_{2i}x_2))
# \end{align}
#
# Instead of this iterative way we can compute this much more efficently in python using matrix multiplication.

# %% [markdown]
# <hr />
#
# ## Task 1a. (2 Points)
#
# **Given:**
#
# The $NN(x,W,u)$ from above consiting of two input nodes, one hidden layer with three nodes and a single output node.
#
# Assume all weights are equal to 1: $w_{ji}=1$ and $u_i=1$.
#
# **Activation Function:**
#
# We will use the **relu** activation function:
#
# \begin{equation*}
#   \sigma(x) = relu(x) =
#   \begin{cases}
#     x & \text{if } x > 0 \\
#     0 & \text{else}
#   \end{cases}
# \end{equation*}
#
# **Compute the output fo the larger network by hand**:
#
# Compute the output $NN(x, W, u)$ for:
#
# * $x_1=1$ and $x_2=1$
# * $x_1 = 1$ and $x_2=-1$

# %% [markdown]
# ## 📢 **HAND-IN** 📢: in Moodle
#
# * Task a1: Output of the network for $x_1=1$ and $x_2=1$
# * Task a2: Output of the network for $x_1=1$ and $x_2=-1$

# %% [markdown]
# <hr />
#
# ## Task 2: A simple numpy-only implementation of a neural network (5 Points)
#
# In this task we will implement the above network $NN(x, W, u)$ in numpy and apply it to address the XOR-problem.
#
# In the next cell, we set up the simplest instance of the XOR-problem with 4 data points.
#
# **Observe that the classes in this problem are not linearly separable, i.e. there is no straight line that can separate the two classes.**

# %%
X = np.array([
    [-1, -1],
    [-1, 1],
    [1, -1],
    [1, 1],
])

y = np.array([1, 0, 0, 1])

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = np.array([
#       2     [-1, -1],
#       3     [-1, 1],
#       4     [1, -1],
#       5     [1, 1],
#       6 ])
#       8 y = np.array([1, 0, 0, 1])
#      10 plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap="coolwarm")
#
# NameError: name 'np' is not defined

# %% [markdown]
# In the next cell, we randomly initialise set the initial weights of our network $W$ and $u$.
# They will then updated during training via gradient descent.

# %%
rng = np.random.default_rng(RANDOM_SEED)

def initialize_weights():
    """
    Randomly initialize the weight matrices W, u

    Returns:
      W: matrix with shape (2,3) and values in range [-1, 1]
      u: vector with shape (3,1) and values in range [-1, 1]
    """

    W = 2.*rng.random((2, 3)) - 1.
    u = 2 * rng.random(3) - 1.

    return W, u

W, u = initialize_weights()

print('W =', W)
print('u =', u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rng = np.random.default_rng(RANDOM_SEED)
#       3 def initialize_weights():
#       4     """
#       5     Randomly initialize the weight matrices W, u
#       6
#    (...)      9       u: vector with shape (3,1) and values in range [-1, 1]
#      10     """
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Activation function
#
# We will use the **relu** activation as the activation function for the network:
#
# \begin{equation}
#   relu(x) =
#   \begin{cases}
#     x & \text{if } x > 0 \\
#     0 & \text{else}
#   \end{cases}
# \end{equation}

# %%
def activation(x: np.array) -> np.array:
  """
  Compute relu activation for a given input

  x: a numpy array of any shape (containing floats)
  """
  return np.maximum(0., x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 def activation(x: np.array) -> np.array:
#       2   """
#       3   Compute relu activation for a given input
#       4
#       5   x: a numpy array of any shape (containing floats)
#       6   """
#       7   return np.maximum(0., x)
#
# NameError: name 'np' is not defined

# %% [markdown]
# The derivative of the *relu* function is undefined at $x = 0$.Therefore we set it to $0$ at that point and define it as:
#
# \begin{equation}
#   \frac{\mathrm{d}}{\mathrm{d}x}relu(x) =
#   \begin{cases}
#     1 & \text{if } x > 0 \\
#     0 & \text{else}
#   \end{cases}
# \end{equation}

# %%
def derivative_activation(x: np.array) -> np.array:
  """
  Compute the derivative of relu activation for a given input.

  x: a numpy array of any shape (containing floats)
  """
  # the comparison here results in an array of booleans, which we cast to float
  return (x > 0.).astype(float)

# %% [markdown]
# <hr />
#
# ### Task 2a. Implement the forward pass
#
# You can now compute the output of the neural network
# for a given input $(x_1, x_2)$.
#
# We call this computation the *forward pass* of the network, because we pass values through the network layer by layer from input to output.
#
# The equation below, provides you the function computed by the network for a single input $x$.

# %% [markdown]
# \begin{align}
#   NN(x, W, u) &= \sigma(u_1\sigma(w_{11}x_1 + w_{21}x_2) + u_2\sigma(w_{12}x_1 + w_{22}x_2) + u_3\sigma(w_{13}x_1 + w_{23}x_2)) \\
#   &= \sigma(\sum_{i = 1}^{3} u_i\sigma(w_{1i}x_1 + w_{2i}x_2))
# \end{align}

# %% [markdown]
# **Make sure to make the implementation as efficiently as possible using matrix/vector multiplications!**

# %%
def forward_pass(
  x: np.array,
  W: np.array,
  u: np.array,
):
    """
    Implement the forward pass for our network NN(x, W, u)

    Parameters:
      x: a 2-element vector containing x_1 and x_2 (numpy array of shape (2,))
      W: a 2x3 matrix containing weights w_ji (numpy array of shape (2, 3))
      u: a 3-element vector containing u_i (numpy array of shape (3,))

    Returns:
      y: prediction of what y should be like

    In this notation the index i goes from 1 to 3 and refers to hidden nodes
    the index j goes from 1 to 2 and indexes the input dimensions

    Note: numpy array indices start from 0 not from 1
    """

    # compute the output of the hidden layer
    hidden_layer_output = activation(x.T @ W)
    # compute the output of the network
    y_hat = activation(u @ hidden_layer_output)

    return y_hat

# %% [markdown]
# In the next cell, we compute the predictions of our network for our data:

# %%
print("index", "x", "y", "prediction", sep="\t")
for i in range(4):
  print(i, X[i, :], y[i], forward_pass(X[i, :], W, u), sep="\t")
# Out:
# index	x	y	prediction
# 0	[-1 -1]	1	0.11007837480005991
# 1	[-1  1]	0	0.6756407940564695
# 2	[ 1 -1]	0	1.188635422350682
# 3	[1 1]	1	0.6284939226766805

# %% [markdown]
# These are the prediction results after the first forward pass with the random initialized weights.

# %% [markdown]
# <hr />
#
# ### Gradient Descent
#
# In the next cell, we implement gradient descent which we need for the cost minimization. For this purpose we need to compute all partial derivatives for the weights (model parameters) of our small network.
#
# **In the next lab, we'll see the details on how to calculate these "Derivatives for a larger Network".** For know it is sufficient to understand that this function computes the partial derivatives needed for the gradient descent.

# %%
def grads(y, x, W, u):
  """
  Compute all partial derivatives of the loss at the sample x, y
  for all weights u_i and w_ji in our network

  Parameters:
    y: float indicating the true label of the sample (either 0. or 1.)
    x: a 2-element vector containing x_1 and x_2 of our sample (numpy array of shape (2,))
    W: a 2x3 matrix containing weights w_ji (numpy array of shape (2, 3))
    u: a 3-element vector containing u_i (numpy array of shape (3,))

  Returns:
    grad_u: a 3-element vector containing partial derivatives d/du_i
    grad_w: a 2x3 matrix containing partial derivatives d/dw_ji
  """
  pred = forward_pass(x, W, u)

  # compute derivative of our squared error loss
  derivative_loss = 2*(pred - y)

  # compute derivative of the output activation
  deriv_output = derivative_activation(u @ activation(x.T @ W))

  grad_u = np.zeros_like(u)
  for i in range(3):
    # compute derivatives with respect to u_i according to the formula in Task 1
    grad_u[i] = derivative_loss * deriv_output * activation(W[:, i] @ x)

  grad_w = np.zeros_like(W)
  for i in range(3):
    for j in range(2):
      # compute derivatives with respect to w_ji according to the formula in Task 1
      grad_w[j, i] = derivative_loss * deriv_output * u[i] * derivative_activation(W[:, i] @ x) * x[j]

  return grad_u, grad_w

# %% [markdown]
# <hr />
#
# ### Task 2b. Training the network using Stochastic Gradient Descent
#
# Below we give you the setup for the main learning loop.
# Your task is to implement the weight updates according to stochastic gradient descent.
#
# **For stochastic gradient descent, at each time step $t$ we sample one data point $x^{(t)}$ and its label (the desired output) $y^{(t)}$.**
#
# We calculate the loss $L$ at time $t$:
#
# \begin{align}
# L^{(t)} = \mathcal{L}(y^{(t)}, NN(x^{(t)}, W, u))
# \end{align}
#
# Then we update our weights as follows:
#
# \begin{align}
#   u_{i}^{(t+1)} = u_{i}^{(t)} - \alpha \frac{\mathrm{d}}{\mathrm{d}u_i}L^{(t)} \\
#   w_{ji}^{(t+1)} = w_{ji}^{(t)} - \alpha \frac{\mathrm{d}}{\mathrm{d}w_{ji}}L^{(t)} \\
# \end{align}
#
# where $\alpha$ denotes the learning rate.
#
# > *__Note__: In this simple example where we try to learn a very simple xor-function we only have 4 samples. To show the learning dynamics we choose stochastic gradient descent.*

# %% [markdown]
# **Adjust the code by**
# - Specifying a learning_rate $\alpha$
# - Specifying a maximum number of update steps `n_steps`
# - Implementing the weight updates for $W$ and $u$

# %% [markdown]
# > **Note**: Because the weights are randomly inizialized and the samples are randomly choosen you can try to run the cell multiple times for the same values of the hyperparameters (the learning rate and the number of iterations).

# %%
W, u = initialize_weights()

learning_rate = 0.1   # choose a learning rate
n_steps = 10         # choose a number of training iterations

losses = []

for t in range(n_steps):

  # randomly sample one of the 4 data points
  sample_ix = rng.integers(0,4)
  x_t = X[sample_ix]
  y_t = y[sample_ix]

  # compute and log squared error for the current sample
  loss = 0.5 * (y_t - forward_pass(x_t, W, u))**2
  losses.append(loss)

  # compute gradients (partial derivatives of our weights)
  grad_u, grad_w = grads(y_t, x_t, W, u)

  # update the weights (model parameters)
  W = W - learning_rate * grad_w
  u = u - learning_rate * grad_u

# plot learning curve
plt.plot(np.arange(n_steps), losses)
plt.show()

# %% [markdown]
# In the next cell, we compute the predictions of our network on our data after training the model:

# %%
print("index", "x", "y", "prediction", sep="\t")
for i in range(4):
  print(i, X[i, :], y[i], forward_pass(X[i, :], W, u), sep="\t")
# Out:
# index	x	y	prediction
# 0	[-1 -1]	1	0.0
# 1	[-1  1]	0	0.011585023123210792
# 2	[ 1 -1]	0	0.048951235457869724
# 3	[1 1]	1	0.0

# %% [markdown]
# ## 📢 **HAND-IN** 📢: in Moodle
#
# * Your implementation of `forward_pass`
# * The implementation of the weight updates
# * Plot of your learning curve

# %% [markdown]
# <hr />
#
# ## Task 3: Neural Networks in Keras (3 Points)
#
# We will now implement the network from above in [Keras](https://keras.io/).
#
# It is a relatively simple and user friendly library to implement neural networks.

# %%
# !pip uninstall keras tensorflow --yes
# !pip install keras tensorflow-macos tensorflow-metal
# Out:
# Found existing installation: keras 3.11.3
# Uninstalling keras-3.11.3:
#   Successfully uninstalled keras-3.11.3
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
# Collecting keras
#   Using cached keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting tensorflow-macos
#   Downloading tensorflow_macos-2.16.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting tensorflow-metal
#   Downloading tensorflow_metal-1.2.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (1.3 kB)
# Requirement already satisfied: absl-py in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (2.3.3)
# Requirement already satisfied: rich in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from keras) (25.0)
# Collecting tensorflow==2.16.2 (from tensorflow-macos)
#   Downloading tensorflow-2.16.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.5)
# Requirement already satisfied: setuptools in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.76.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting numpy (from keras)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Using cached keras-3.11.3-py3-none-any.whl (1.4 MB)
# Downloading tensorflow_macos-2.16.2-cp312-cp312-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow-2.16.2-cp312-cp312-macosx_12_0_arm64.whl (227.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 MB 20.2 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_metal-1.2.0-cp312-cp312-macosx_12_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl (393 kB)
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 12.7 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 13.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tensorflow-metal, protobuf, numpy, tensorboard, ml-dtypes, keras, tensorflow, tensorflow-macos
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.20.0
#     Uninstalling tensorboard-2.20.0:
#       Successfully uninstalled tensorboard-2.20.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.3
#     Uninstalling ml_dtypes-0.5.3:
#       Successfully uninstalled ml_dtypes-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.2.3.250308 requires types-pytz>=2022.1.1, which is not installed.
# Successfully installed keras-3.11.3 ml-dtypes-0.3.2 numpy-1.26.4 protobuf-4.25.8 tensorboard-2.16.2 tensorflow-2.16.2 tensorflow-macos-2.16.2 tensorflow-metal-1.2.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

RANDOM_SEED = 0xdeadbeef

X, y = make_blobs(
  n_samples=1000,
  n_features=2,
  centers=np.array([
    [-1, -1],
    [-1, 1],
    [1, -1],
    [1, 1]
  ]),
  cluster_std=.25,
  shuffle=True,
  random_state=RANDOM_SEED,
)
y[y == 2] = 1
y[y == 3] = 0

plt.scatter(X[:, 0],X[:, 1],c=y,s=20,cmap="bwr")
plt.show()

# %%
from keras import Sequential
from keras.layers import Activation, Dense

# %% [markdown]
# Below we implement the exact same neural network that we have been working with so far.
#
# First we define an empty `Sequential` model. This is the most common type of model, where values are passed from layer to layer sequentially.
#
# We then add various layers to our model. We use two types of layers: `Dense` and `Activation`.
#
# The `Dense` layer implements the weighted sum and the `Activation` layer implements the activation function.
#
# A `Dense` layer implements a simple linear transform (matrix multiplication + bias). For a given input $x$ it computes: $Wx + b$. The matrix $W$ contains the weights of the layer and $b$ is the bias term. Note that in our original network we did not use any biases, so we set `use_bias=False` below. The first argument to the `Dense` class defines the number of outputs of the layer. The argument `input_shape` defines the number of inputs.
#
# An `Activation` layer implements the various activation functions. We use *relu* activations, as in our hand-made network above. Activation functions are applied **separately** to each node and we therefore do not have to define input and output dimensions.
#
# Check the [Keras Documentation](https://keras.io/guides/sequential_model/) for further details.
#
# > **Note:** that in our original network we did not use any biases, so we set `use_bias=False` below.

# %%
model = Sequential()
model.add(Dense(3, input_shape=(2,), use_bias=False))
model.add(Activation("relu"))
model.add(Dense(1, input_shape=(3,), use_bias=False))
model.add(Activation("relu"))
# Out:
# /Users/jonas/miniconda3/envs/MLDM/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-24 11:08:32.686893: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-10-24 11:08:32.686953: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-10-24 11:08:32.686961: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.72 GB
# 2025-10-24 11:08:32.687014: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-24 11:08:32.687041: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# **Before you continue**, compute the number of model parameters of this neural network.
#
# The method `model.summary()` gives an overview of the different layers in our models, showing in particular the number of trainable parameters in our network.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# In the next cell, we prepare the model for training using the `.compile` method.
#
# To stay consistent with the step-by-step implementation from the previous task, we choose `optimizer="sgd"` for "stochastic gradient descent".
#
# We choose `loss="mse"` (even though for classification, `loss="binary_crossentropy"` would be more appropriate, but again we want to stay close to the manual example above).
#
# By default, keras will log the loss during training.
# We can additionally ask it to compute and log additional metrics.
# Below, we pass `metrics=['accuracy']` to also log accuracy while training.
#
# > *__Note__: `accuracy` and `loss` will be computed and logged on the __training data__*

# %%
model.compile(optimizer="sgd", loss="mse", metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=10, batch_size=1)
# Out:
# Epoch 1/10
# 2025-10-24 11:08:42.731357: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5000 - loss: 0.5002
# Epoch 2/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5000 - loss: 0.5001
# Epoch 3/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5000 - loss: 0.5000
# Epoch 4/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5000 - loss: 0.4996
# Epoch 5/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6790 - loss: 0.3104
# Epoch 6/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7490 - loss: 0.2593
# Epoch 7/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7490 - loss: 0.2590
# Epoch 8/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7490 - loss: 0.2591
# Epoch 9/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7490 - loss: 0.2590
# Epoch 10/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7490 - loss: 0.2589

# %% [markdown]
# We can use the History object to plot the learning curve and accuracy over time (where time is measured in epochs, meaning number of passes over the full data set).

# %%
plt.plot(history.history['loss'], label="Loss")
plt.plot(history.history['accuracy'], label="Accuracy")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# In the next cell we will plot decision boundaries to better understand what the model has learned.

# %%
def plot_model_out(x_space,y_space,model):
  """
  Parameters:
    x_space,y_space: 2D MeshGrid input
    model: Keras Model API Object
  """
  grid = np.stack((x_space,y_space))
  grid = grid.T.reshape(-1,2)
  outs = model.predict(grid)
  y1 = outs.T[0].reshape(x_space.shape[0],x_space.shape[0])
  plt.contourf(x_space,y_space,y1,alpha=.6,cmap="coolwarm")

# %%
a = np.linspace(-2, 2, 100)
x_space, y_space = np.meshgrid(a,a)
plot_model_out(x_space,y_space,model)
plt.scatter(X[:, 0], X[:, 1],c=y,s=20,cmap="bwr")
plt.colorbar()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step

# %%
# for reproducibility
from tensorflow import keras
keras.utils.set_random_seed(999)

model = Sequential()
model.add(Dense(3, input_shape=(2,), use_bias=True))
model.add(Activation("sigmoid"))
model.add(Dense(1, input_shape=(3,), use_bias=True))
model.add(Activation("sigmoid"))
model.compile(optimizer="sgd", loss="mse", metrics=['accuracy'])

history = model.fit(X, y, epochs=150, batch_size=5)

plt.plot(history.history['loss'], label="Loss")
plt.plot(history.history['accuracy'], label="Accuracy")
plt.grid()
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6460 - loss: 0.2523
# Epoch 2/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6480 - loss: 0.2517
# Epoch 3/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6480 - loss: 0.2510
# Epoch 4/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6480 - loss: 0.2504
# Epoch 5/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6490 - loss: 0.2499
# Epoch 6/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6500 - loss: 0.2493
# Epoch 7/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6520 - loss: 0.2487
# Epoch 8/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6530 - loss: 0.2482
# Epoch 9/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6560 - loss: 0.2476
# Epoch 10/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6590 - loss: 0.2471
# Epoch 11/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6590 - loss: 0.2466
# Epoch 12/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6600 - loss: 0.2461
# Epoch 13/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6640 - loss: 0.2455
# Epoch 14/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6650 - loss: 0.2450
# Epoch 15/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6670 - loss: 0.2444
# Epoch 16/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6700 - loss: 0.2439
# Epoch 17/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6760 - loss: 0.2433
# Epoch 18/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6770 - loss: 0.2428
# Epoch 19/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6780 - loss: 0.2422
# Epoch 20/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6790 - loss: 0.2416
# Epoch 21/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6820 - loss: 0.2410
# Epoch 22/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6860 - loss: 0.2403
# Epoch 23/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6880 - loss: 0.2397
# Epoch 24/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6910 - loss: 0.2390
# Epoch 25/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6920 - loss: 0.2383
# Epoch 26/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6950 - loss: 0.2376
# Epoch 27/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6970 - loss: 0.2369
# Epoch 28/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6970 - loss: 0.2362
# Epoch 29/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7010 - loss: 0.2354
# Epoch 30/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7050 - loss: 0.2346
# Epoch 31/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7060 - loss: 0.2338
# Epoch 32/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7090 - loss: 0.2329
# Epoch 33/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7120 - loss: 0.2320
# Epoch 34/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7160 - loss: 0.2311
# Epoch 35/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7170 - loss: 0.2302
# Epoch 36/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7200 - loss: 0.2293
# Epoch 37/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7220 - loss: 0.2283
# Epoch 38/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7260 - loss: 0.2273
# Epoch 39/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7280 - loss: 0.2262
# Epoch 40/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7300 - loss: 0.2252
# Epoch 41/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7300 - loss: 0.2241
# Epoch 42/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7310 - loss: 0.2230
# Epoch 43/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7330 - loss: 0.2218
# Epoch 44/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7360 - loss: 0.2207
# Epoch 45/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7380 - loss: 0.2195
# Epoch 46/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7390 - loss: 0.2183
# Epoch 47/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7400 - loss: 0.2170
# Epoch 48/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7410 - loss: 0.2158
# Epoch 49/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7410 - loss: 0.2145
# Epoch 50/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7410 - loss: 0.2132
# Epoch 51/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7430 - loss: 0.2119
# Epoch 52/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7440 - loss: 0.2105
# Epoch 53/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7440 - loss: 0.2092
# Epoch 54/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7450 - loss: 0.2078
# Epoch 55/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7450 - loss: 0.2064
# Epoch 56/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7450 - loss: 0.2050
# Epoch 57/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7450 - loss: 0.2035
# Epoch 58/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7460 - loss: 0.2021
# Epoch 59/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7460 - loss: 0.2006
# Epoch 60/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7460 - loss: 0.1991
# Epoch 61/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7460 - loss: 0.1977
# Epoch 62/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7460 - loss: 0.1961
# Epoch 63/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1946
# Epoch 64/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1931
# Epoch 65/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1916
# Epoch 66/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1900
# Epoch 67/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1884
# Epoch 68/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1869
# Epoch 69/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7470 - loss: 0.1853
# Epoch 70/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7480 - loss: 0.1837
# Epoch 71/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7490 - loss: 0.1821
# Epoch 72/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7490 - loss: 0.1805
# Epoch 73/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.1788
# Epoch 74/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7510 - loss: 0.1772
# Epoch 75/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7520 - loss: 0.1756
# Epoch 76/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7540 - loss: 0.1739
# Epoch 77/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7580 - loss: 0.1723
# Epoch 78/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7630 - loss: 0.1706
# Epoch 79/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7680 - loss: 0.1689
# Epoch 80/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7740 - loss: 0.1673
# Epoch 81/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7810 - loss: 0.1656
# Epoch 82/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7910 - loss: 0.1639
# Epoch 83/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7940 - loss: 0.1622
# Epoch 84/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8050 - loss: 0.1605
# Epoch 85/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8120 - loss: 0.1588
# Epoch 86/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8190 - loss: 0.1571
# Epoch 87/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8310 - loss: 0.1554
# Epoch 88/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8430 - loss: 0.1537
# Epoch 89/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8590 - loss: 0.1520
# Epoch 90/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8700 - loss: 0.1503
# Epoch 91/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8820 - loss: 0.1486
# Epoch 92/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8930 - loss: 0.1468
# Epoch 93/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9130 - loss: 0.1451
# Epoch 94/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9210 - loss: 0.1434
# Epoch 95/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9310 - loss: 0.1417
# Epoch 96/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9390 - loss: 0.1400
# Epoch 97/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9420 - loss: 0.1383
# Epoch 98/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9510 - loss: 0.1365
# Epoch 99/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9560 - loss: 0.1348
# Epoch 100/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9670 - loss: 0.1331
# Epoch 101/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9700 - loss: 0.1314
# Epoch 102/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9740 - loss: 0.1297
# Epoch 103/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9790 - loss: 0.1280
# Epoch 104/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9840 - loss: 0.1263
# Epoch 105/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9860 - loss: 0.1247
# Epoch 106/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9870 - loss: 0.1230
# Epoch 107/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9890 - loss: 0.1213
# Epoch 108/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9910 - loss: 0.1197
# Epoch 109/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.1180
# Epoch 110/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.1164
# Epoch 111/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.1147
# Epoch 112/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.1131
# Epoch 113/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.1115
# Epoch 114/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.1099
# Epoch 115/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9980 - loss: 0.1084
# Epoch 116/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9980 - loss: 0.1068
# Epoch 117/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.1052
# Epoch 118/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.1037
# Epoch 119/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.1022
# Epoch 120/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9990 - loss: 0.1007
# Epoch 121/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0992
# Epoch 122/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0977
# Epoch 123/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0962
# Epoch 124/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0948
# Epoch 125/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0934
# Epoch 126/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0920
# Epoch 127/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0906
# Epoch 128/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0892
# Epoch 129/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0879
# Epoch 130/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0865
# Epoch 131/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0852
# Epoch 132/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0839
# Epoch 133/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0826
# Epoch 134/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0814
# Epoch 135/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0801
# Epoch 136/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0789
# Epoch 137/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0777
# Epoch 138/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0765
# Epoch 139/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0754
# Epoch 140/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0742
# Epoch 141/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0731
# Epoch 142/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0720
# Epoch 143/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0709
# Epoch 144/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0698
# Epoch 145/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0688
# Epoch 146/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0677
# Epoch 147/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0667
# Epoch 148/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0657
# Epoch 149/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0647
# Epoch 150/150
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0638

# %% [markdown]
# ### Task 3a.
#
# What could we change so that we obtain better quality predictions?
#
# Change one of these options at a time and try to understand what their influence on the result is?
#
# **Model Options:**
#
# - Increase the number of hidden nodes
# - Increase the number of layers
# - Change to `use_bias=True`
# - Change the `Activation` function
#
# **Compile Options:**
#
# - Change the `optimizer` (Check the available options in the [Keras Documentation](https://keras.io/api/optimizers/#available-optimizers))
# - Change the `loss` to `binary_crossentropy`
#
#
# **Fit Options:**
#
# - Change the number of `epochs`
# - Change the `batch_size`
#
#
# **Which option has the biggest impact on the performance of the model?**

# %% [markdown]
# ## 📢 **HAND-IN** 📢: in Moodle
#
# * the option that worked best for you
# * the final accuracy you achieved using it
